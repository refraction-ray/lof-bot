# %% [markdown]
# # 寻找各种 QDII 基金额度耗尽后的可能替代品

# %%
import sys
sys.path.insert(0, "../")
# %load_ext autoreload
# %autoreload 2
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib notebook
import xalpha as xa
xa.set_backend(backend="csv", path="../data", precached="20170103")

# %% [markdown]
# ## 原油 FOF

# %%
c = xa.Compare("F161815", ("8833", "USD"),"F165513", "F501018","F050020", start="20190101")

# %%
c.v()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
c.corr() # 165513 更好些 050020 也可备用，作为原油替代
# Out:
#           F161815      8833   F165513   F501018   F050020
# F161815  1.000000  0.811705  0.900413  0.862214  0.875923
# 8833     0.811705  1.000000  0.901052  0.904243  0.904696
# F165513  0.900413  0.901052  1.000000  0.925148  0.925680
# F501018  0.862214  0.904243  0.925148  1.000000  0.912387
# F050020  0.875923  0.904696  0.925680  0.912387  1.000000

# %% [markdown]
# ## 油气类股票基金

# %%
c=xa.Compare("F162719", "F160416", "F378546", start="20190101")
c.v()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
c.corr() ## 378546 用来轮动 160416 是没问题的
# Out:
#           F162719   F160416   F378546
# F162719  1.000000  0.933609  0.829095
# F160416  0.933609  1.000000  0.905209
# F378546  0.829095  0.905209  1.000000

# %% [markdown]
# ## 美股

# %%
c=xa.Compare("F161130", "F006075", "F161128", "F161127","F000988", "F100055","F001668", start="20190101")

# %%
c.v()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
c.corr() # 标普生科1127，这两年不太行啊，标普500 060075 也一般； 纳斯达克100， 嘉实全球互联网差不多
# 看关联， nasdaq 最佳替代是标普科技，其次是嘉实全球互联网000988， 富国互联和其他关联一般
# Out:
#           F161130   F006075   F161128   F161127   F000988   F100055   F001668
# F161130  1.000000  0.969519  0.987663  0.810793  0.946148  0.719316  0.890882
# F006075  0.969519  1.000000  0.969421  0.803433  0.892910  0.703441  0.869903
# F161128  0.987663  0.969421  1.000000  0.786584  0.927097  0.720770  0.891074
# F161127  0.810793  0.803433  0.786584  1.000000  0.788538  0.597033  0.732024
# F000988  0.946148  0.892910  0.927097  0.788538  1.000000  0.783745  0.932434
# F100055  0.719316  0.703441  0.720770  0.597033  0.783745  1.000000  0.899749
# F001668  0.890882  0.869903  0.891074  0.732024  0.932434  0.899749  1.000000

# %% [markdown]
# ## 欧洲

# %%
c=xa.Compare("F513030", "F539003", "F000614", start="20200201")
c.v()
# Out:
# ...
# <img src="data:image/png;base64,..." width="640">

# %%
c.corr() ## 英国和德国，无奈情形，也只能替代了，勉强可以接受, 德国场外最后走的和英国一样也是醉了
# Out:
#           F513030   F539003   F000614
# F513030  1.000000  0.919129  0.970437
# F539003  0.919129  1.000000  0.890122
# F000614  0.970437  0.890122  1.000000

# %% [markdown]
# ## 日本

# %%
c=xa.Compare("F513000", "F007280", start="20200101")
c.v()
# Out:
# ...
# <img src="data:image/png;base64,..." width="640">

# %%
c.corr() ## 相关性一般，但总趋势还好，比较一致，不过关联性较低，要谨慎
# Out:
#           F513000   F007280
# F513000  1.000000  0.768568
# F007280  0.768568  1.000000

# %% [markdown]
# ## 中国互联

# %%
c=xa.Compare("F164906", "F513050", "F160644", "F100055", "F001668", start="20190101")
c.v()
# Out:
# ...
# <img src="data:image/png;base64,..." width="640">

# %%
c.corr() ## 这两个 有点内味了，和两个互联走势高度一致啊，但由于主动型手续费高，似乎还是略有跑输，不过真到两只互联关门，也是可以研究下
## 001668 还是跟美股互联网多于中概
# Out:
#           F164906   F513050   F160644   F100055   F001668
# F164906  1.000000  0.973985  0.886807  0.917292  0.871767
# F513050  0.973985  1.000000  0.904779  0.906662  0.879399
# F160644  0.886807  0.904779  1.000000  0.895027  0.932202
# F100055  0.917292  0.906662  0.895027  1.000000  0.900272
# F001668  0.871767  0.879399  0.932202  0.900272  1.000000
